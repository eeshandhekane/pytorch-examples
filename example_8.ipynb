# %%
# Dependencies
import torch.nn as nn

# %matplotlib inline

# %%
"""
Models in pytorch are based on two main classes--
1. `torch.nn.Module`
    Encapsulates models and their components, e.g., neural nets and layers.
2. `torch.nn.Parameter`
    Parameters are subclass of `torch.Tensor` and represent learning weights.
    When a parameter is assigned as an attribute of a model, the parameter object gets registered with that module.
    When a module instance is an attribute of a model, its parameters are also registered as that of the owning class.
"""
# Out:
# '\nModels in pytorch are based on two main classes--\n1. `torch.nn.Module`\n    Encapsulates models and their components, e.g., neural nets and layers.\n2. `torch.nn.Parameter`\n    Parameters are subclass of `torch.Tensor` and represent learning weights.\n    When a parameter is assigned as an attribute of a model, the parameter object gets registered with that module.\n    When a module instance is an attribute of a model, its parameters are also registered as that of the owning class.\n'

# %%
input_dim: int = 10
hidden_dim: int = 5
output_dim: int = 2
batch_size: int = 4

# %%
class Model(nn.Module):
    r"""A basic example model.
    """

    #
    def __init__(self):
        r"""The initializer.
        """
        super(Model, self).__init__()
        self.layer1 = nn.Linear(in_features=input_dim, out_features=hidden_dim)
        self.act1 = nn.ReLU()
        self.layer2 = nn.Linear(in_features=hidden_dim, out_features=output_dim)
        self.act2 = nn.Softmax()

    #
    def forward(self, x_):
        r"""Implements the forward pass.

        Parameters
        ----------
        x_:
            Input tensor.
            SHAPE: [*<batch_sizes>, input_dim].

        Returns
        -------
        out:
            Output tensor.
            SHAPE: [*<batch_sizes>, output_dim].
        """
        return self.act2(self.layer2(self.act1(self.layer1(x_))))

# %%
model = Model()
print('model:\n{}'.format(model))
print('*'*79)
print('model parameters type:\n{}\nlength: {}'.format(
    type(model.parameters()), len([_ for _ in model.parameters()])
))  # Generator instance.
print('*'*79)
print('model parameters instance type:\n{}'.format(
    type([_ for _ in model.parameters()][0])
))  # `torch.nn.Parameter` instance.
print('*'*79)
print('model parameters 0-th instance:\n{}'.format(
    [_ for _ in model.parameters()][0]
))
print('*'*79)
print('model parameters:\n{}'.format([_ for _ in model.parameters()]))
print('*'*79)
print('model named parameters type:\n{}\nlength: {}'.format(
    type(model.named_parameters()),
    len([_ for _ in model.named_parameters()])
))  # Generator instance.
print('*'*79)
print('model named parameters instance type:\n{}\nlength: {}'.format(
    type([_ for _ in model.named_parameters()][0]),
    len([_ for _ in model.named_parameters()][0])
))  # `Tuple`, 2
print('*'*79)
print('model named parameters attributes instance type:\n{}, {}'.format(
    type([_ for _ in model.named_parameters()][0][0]),
    type([_ for _ in model.named_parameters()][0][1])
))  # `str`, `torch.nn.Parameter`
print('*'*79)
for named_parameter in model.named_parameters():
    print('name of the parameter: {}\nvalue:\n{}'.format(named_parameter[0], named_parameter[1]))
    print('*'*39)
# Out:
# model:
# Model(
#   (layer1): Linear(in_features=10, out_features=5, bias=True)
#   (act1): ReLU()
#   (layer2): Linear(in_features=5, out_features=2, bias=True)
#   (act2): Softmax(dim=None)
# )
# *******************************************************************************
# model parameters type:
# <class 'generator'>
# length: 4
# *******************************************************************************
# model parameters instance type:
# <class 'torch.nn.parameter.Parameter'>
# *******************************************************************************
# model parameters 0-th instance:
# Parameter containing:
# tensor([[-0.1021,  0.1046, -0.1670, -0.1134,  0.2864,  0.3161, -0.2662,  0.2645,
#          -0.1393, -0.1636],
#         [ 0.0553, -0.1285, -0.0282,  0.3058, -0.1665, -0.1441, -0.0580, -0.1139,
#          -0.0469,  0.1676],
#         [-0.0769, -0.1688,  0.0229,  0.1075, -0.0738, -0.2767, -0.2210,  0.1862,
#           0.0562,  0.2376],
#         [ 0.0818, -0.2843,  0.0921,  0.3091,  0.1554, -0.0688,  0.2361, -0.3134,
#           0.1612, -0.3060],
#         [-0.1447, -0.1402, -0.2425, -0.0482,  0.1836,  0.0423, -0.1611, -0.2022,
#           0.1788, -0.2048]], requires_grad=True)
# *******************************************************************************
# model parameters:
# [Parameter containing:
# tensor([[-0.1021,  0.1046, -0.1670, -0.1134,  0.2864,  0.3161, -0.2662,  0.2645,
#          -0.1393, -0.1636],
#         [ 0.0553, -0.1285, -0.0282,  0.3058, -0.1665, -0.1441, -0.0580, -0.1139,
#          -0.0469,  0.1676],
#         [-0.0769, -0.1688,  0.0229,  0.1075, -0.0738, -0.2767, -0.2210,  0.1862,
#           0.0562,  0.2376],
#         [ 0.0818, -0.2843,  0.0921,  0.3091,  0.1554, -0.0688,  0.2361, -0.3134,
#           0.1612, -0.3060],
#         [-0.1447, -0.1402, -0.2425, -0.0482,  0.1836,  0.0423, -0.1611, -0.2022,
#           0.1788, -0.2048]], requires_grad=True), Parameter containing:
# tensor([0.0502, 0.0859, 0.1637, 0.0009, 0.1557], requires_grad=True), Parameter containing:
# tensor([[-0.1606,  0.3855,  0.1961, -0.4328, -0.1637],
#         [ 0.0472, -0.0982,  0.1729, -0.0473, -0.0101]], requires_grad=True), Parameter containing:
# tensor([0.0422, 0.4459], requires_grad=True)]
# *******************************************************************************
# model named parameters type:
# <class 'generator'>
# length: 4
# *******************************************************************************
# model named parameters instance type:
# <class 'tuple'>
# length: 2
# *******************************************************************************
# model named parameters attributes instance type:
# <class 'str'>, <class 'torch.nn.parameter.Parameter'>
# *******************************************************************************
# name of the parameter: layer1.weight
# value:
# Parameter containing:
# tensor([[-0.1021,  0.1046, -0.1670, -0.1134,  0.2864,  0.3161, -0.2662,  0.2645,
#          -0.1393, -0.1636],
#         [ 0.0553, -0.1285, -0.0282,  0.3058, -0.1665, -0.1441, -0.0580, -0.1139,
#          -0.0469,  0.1676],
#         [-0.0769, -0.1688,  0.0229,  0.1075, -0.0738, -0.2767, -0.2210,  0.1862,
#           0.0562,  0.2376],
#         [ 0.0818, -0.2843,  0.0921,  0.3091,  0.1554, -0.0688,  0.2361, -0.3134,
#           0.1612, -0.3060],
#         [-0.1447, -0.1402, -0.2425, -0.0482,  0.1836,  0.0423, -0.1611, -0.2022,
#           0.1788, -0.2048]], requires_grad=True)
# ***************************************
# name of the parameter: layer1.bias
# value:
# Parameter containing:
# tensor([0.0502, 0.0859, 0.1637, 0.0009, 0.1557], requires_grad=True)
# ***************************************
# name of the parameter: layer2.weight
# value:
# Parameter containing:
# tensor([[-0.1606,  0.3855,  0.1961, -0.4328, -0.1637],
#         [ 0.0472, -0.0982,  0.1729, -0.0473, -0.0101]], requires_grad=True)
# ***************************************
# name of the parameter: layer2.bias
# value:
# Parameter containing:
# tensor([0.0422, 0.4459], requires_grad=True)
# ***************************************

# %%
print('*'*79)
print("model's layer 1 details")
print('*'*79)
print('model1.layer1 parameters:\n{}'.format(
    [_ for _ in model.layer1.parameters()]
))
print('*'*79)
print('model1.layer1 named parameters:\n{}'.format(
    [_ for _ in model.layer1.named_parameters()]
))
# Out:
# *******************************************************************************
# model's layer 1 details
# *******************************************************************************
# model1.layer1 parameters:
# [Parameter containing:
# tensor([[-0.1021,  0.1046, -0.1670, -0.1134,  0.2864,  0.3161, -0.2662,  0.2645,
#          -0.1393, -0.1636],
#         [ 0.0553, -0.1285, -0.0282,  0.3058, -0.1665, -0.1441, -0.0580, -0.1139,
#          -0.0469,  0.1676],
#         [-0.0769, -0.1688,  0.0229,  0.1075, -0.0738, -0.2767, -0.2210,  0.1862,
#           0.0562,  0.2376],
#         [ 0.0818, -0.2843,  0.0921,  0.3091,  0.1554, -0.0688,  0.2361, -0.3134,
#           0.1612, -0.3060],
#         [-0.1447, -0.1402, -0.2425, -0.0482,  0.1836,  0.0423, -0.1611, -0.2022,
#           0.1788, -0.2048]], requires_grad=True), Parameter containing:
# tensor([0.0502, 0.0859, 0.1637, 0.0009, 0.1557], requires_grad=True)]
# *******************************************************************************
# model1.layer1 named parameters:
# [('weight', Parameter containing:
# tensor([[-0.1021,  0.1046, -0.1670, -0.1134,  0.2864,  0.3161, -0.2662,  0.2645,
#          -0.1393, -0.1636],
#         [ 0.0553, -0.1285, -0.0282,  0.3058, -0.1665, -0.1441, -0.0580, -0.1139,
#          -0.0469,  0.1676],
#         [-0.0769, -0.1688,  0.0229,  0.1075, -0.0738, -0.2767, -0.2210,  0.1862,
#           0.0562,  0.2376],
#         [ 0.0818, -0.2843,  0.0921,  0.3091,  0.1554, -0.0688,  0.2361, -0.3134,
#           0.1612, -0.3060],
#         [-0.1447, -0.1402, -0.2425, -0.0482,  0.1836,  0.0423, -0.1611, -0.2022,
#           0.1788, -0.2048]], requires_grad=True)), ('bias', Parameter containing:
# tensor([0.0502, 0.0859, 0.1637, 0.0009, 0.1557], requires_grad=True))]

# %%
# Fully connected linear layer.
print('*'*79)
linear = nn.Linear(in_features=10, out_features=2, bias=True)
print('linear layer:\n{}'.format(linear))
print('*'*79)
print('linear layer parameters:\n{}\nlength: {}'.format(
    [_ for _ in linear.parameters()], len([_ for _ in linear.parameters()])
))
print('*'*79)
print('linear layer named parameters:\n{}\nlength: {}'.format(
    [_ for _ in linear.named_parameters()], len([_ for _ in linear.named_parameters()])
))
print('*'*79)
linear_nobias = nn.Linear(in_features=10, out_features=2, bias=False)
print('linear with no bias layer parameters:\n{}\nlength: {}'.format(
    [_ for _ in linear_nobias.parameters()], len([_ for _ in linear_nobias.parameters()])
))
print('*'*79)
print('linear with no bias layer named parameters:\n{}\nlength: {}'.format(
    [_ for _ in linear_nobias.named_parameters()], len([_ for _ in linear_nobias.named_parameters()])
))
# Out:
# *******************************************************************************
# linear layer:
# Linear(in_features=10, out_features=2, bias=True)
# *******************************************************************************
# linear layer parameters:
# [Parameter containing:
# tensor([[-0.3020, -0.0012, -0.0561, -0.0203, -0.2149, -0.2382, -0.0775, -0.0974,
#           0.1755, -0.2390],
#         [-0.2036, -0.1802, -0.3014, -0.1920,  0.0076,  0.1387, -0.2897,  0.1927,
#           0.0420,  0.1477]], requires_grad=True), Parameter containing:
# tensor([-0.2250,  0.0702], requires_grad=True)]
# length: 2
# *******************************************************************************
# linear layer named parameters:
# [('weight', Parameter containing:
# tensor([[-0.3020, -0.0012, -0.0561, -0.0203, -0.2149, -0.2382, -0.0775, -0.0974,
#           0.1755, -0.2390],
#         [-0.2036, -0.1802, -0.3014, -0.1920,  0.0076,  0.1387, -0.2897,  0.1927,
#           0.0420,  0.1477]], requires_grad=True)), ('bias', Parameter containing:
# tensor([-0.2250,  0.0702], requires_grad=True))]
# length: 2
# *******************************************************************************
# linear with no bias layer parameters:
# [Parameter containing:
# tensor([[-0.1982, -0.1296,  0.0088,  0.0051,  0.1473, -0.2771, -0.1753,  0.0249,
#          -0.3117,  0.1798],
#         [-0.0503, -0.0552, -0.1817,  0.0251,  0.1745, -0.0276, -0.0709, -0.1249,
#          -0.1572, -0.0007]], requires_grad=True)]
# length: 1
# *******************************************************************************
# linear with no bias layer named parameters:
# [('weight', Parameter containing:
# tensor([[-0.1982, -0.1296,  0.0088,  0.0051,  0.1473, -0.2771, -0.1753,  0.0249,
#          -0.3117,  0.1798],
#         [-0.0503, -0.0552, -0.1817,  0.0251,  0.1745, -0.0276, -0.0709, -0.1249,
#          -0.1572, -0.0007]], requires_grad=True))]
# length: 1

# %%
# Convolutional layer.
print('*'*79)
conv2d = nn.Conv2d(kernel_size=(4, 5), in_channels=3, out_channels=6, bias=True)
print('convolutional layer:\n{}'.format(conv2d))
print('*'*79)
for param in conv2d.parameters():
    print('param:\n{}'.format(param))
print('*'*79)
for param in conv2d.named_parameters():
    print('param name: {}\nparam value:\n{}'.format(param[0], param[1]))
print('*'*79)
print('number of parameters: {} (={})'.format(
    len([_ for _ in conv2d.parameters()]), len([_ for _ in conv2d.named_parameters()])
))
print('*'*79)
print('conv layer weight shape: {}'.format(conv2d.weight.shape))  # [<out_channels>, <in_channels>, *<kernel_shape>]
print('conv layer bias shape: {}'.format(conv2d.bias.shape))  # [<out_channels>, ]
# Out:
# *******************************************************************************
# convolutional layer:
# Conv2d(3, 6, kernel_size=(4, 5), stride=(1, 1))
# *******************************************************************************
# param:
# Parameter containing:
# tensor([[[[ 0.0387,  0.1239,  0.0778, -0.1054, -0.0785],
#           [ 0.0686, -0.0441,  0.1030, -0.1146,  0.0502],
#           [-0.0848, -0.0677,  0.0899, -0.1166,  0.0716],
#           [-0.0855,  0.0031,  0.0800,  0.0978, -0.0279]],
#
#          [[-0.0388,  0.0523,  0.0908,  0.0155, -0.1143],
#           [ 0.0673,  0.1113,  0.1271, -0.0353, -0.0797],
#           [ 0.1083, -0.0738,  0.0285, -0.1175,  0.0549],
#           [ 0.0123, -0.0157, -0.0755,  0.0169, -0.1232]],
#
#          [[ 0.0446,  0.0992,  0.0155,  0.0110, -0.0657],
#           [-0.0301,  0.1129,  0.0429, -0.0961,  0.0464],
#           [-0.0254,  0.0151, -0.1281, -0.1192, -0.0042],
#           [-0.1161, -0.0056, -0.1036, -0.1120, -0.0275]]],
#
#
#         [[[-0.0276, -0.1274,  0.1200,  0.0728, -0.0781],
#           [ 0.0503, -0.0444,  0.0349, -0.0902,  0.1009],
#           [ 0.0773,  0.0991, -0.1223,  0.0405,  0.0545],
#           [-0.0153, -0.0044, -0.0881, -0.1129, -0.0490]],
#
#          [[ 0.1279, -0.1193,  0.0865, -0.0482,  0.0793],
#           [ 0.0264,  0.0647, -0.0968, -0.0486,  0.0585],
#           [-0.1159, -0.1173, -0.0581, -0.0679,  0.0054],
#           [-0.0547, -0.0450, -0.1259,  0.0602,  0.0112]],
#
#          [[-0.0944, -0.0915,  0.0515, -0.0467, -0.1130],
#           [-0.0373,  0.0603, -0.0563,  0.0558,  0.0302],
#           [-0.0864, -0.0941,  0.0515,  0.0399,  0.0824],
#           [-0.0399, -0.1228, -0.0576,  0.1249,  0.0927]]],
#
#
#         [[[-0.0276,  0.0098, -0.0822,  0.0349,  0.1058],
#           [ 0.0155,  0.0837, -0.0519,  0.0067,  0.0126],
#           [ 0.0047, -0.1169, -0.0058, -0.0997, -0.0345],
#           [-0.0011, -0.0903,  0.0015,  0.0901, -0.0271]],
#
#          [[ 0.1232,  0.1289,  0.0742, -0.1032, -0.0938],
#           [ 0.0823,  0.0318,  0.0757,  0.1206,  0.1099],
#           [-0.0212,  0.0300,  0.0009, -0.0828, -0.0986],
#           [-0.1023, -0.0367,  0.0073,  0.0543, -0.0307]],
#
#          [[-0.1175, -0.0579,  0.0780, -0.0340, -0.0523],
#           [-0.1213, -0.0219,  0.0264, -0.1001,  0.0251],
#           [ 0.0511,  0.1114,  0.0038,  0.0315,  0.0388],
#           [-0.0934,  0.1284, -0.0717, -0.1256, -0.0640]]],
#
#
#         [[[ 0.0079, -0.0270,  0.0750, -0.0190,  0.1030],
#           [-0.0092,  0.0427,  0.1155, -0.0557,  0.0477],
#           [-0.0105, -0.0310, -0.0840,  0.0863, -0.1061],
#           [ 0.1015,  0.0300,  0.0154,  0.0978, -0.0532]],
#
#          [[-0.0530, -0.1128,  0.0805, -0.0537,  0.0414],
#           [-0.0250, -0.0571, -0.0684, -0.0764,  0.0482],
#           [-0.0944,  0.0935,  0.0958,  0.1070, -0.0584],
#           [-0.1201,  0.0355,  0.0408, -0.0659, -0.1010]],
#
#          [[ 0.1282, -0.0350, -0.0356,  0.0961, -0.1271],
#           [-0.1143, -0.0286,  0.0900,  0.1208, -0.1123],
#           [ 0.0485,  0.0309, -0.0969,  0.0974,  0.1145],
#           [ 0.0005, -0.0475, -0.0373, -0.0894, -0.1263]]],
#
#
#         [[[-0.0638, -0.1116,  0.0288, -0.0626, -0.0006],
#           [-0.0615, -0.0276, -0.0032,  0.1267, -0.0900],
#           [-0.0194,  0.0377, -0.0743, -0.0167,  0.1040],
#           [-0.1144, -0.0862,  0.0144,  0.0886, -0.0310]],
#
#          [[-0.0251,  0.0983, -0.1110,  0.1187,  0.0602],
#           [ 0.0621, -0.0239,  0.0923, -0.0558, -0.0673],
#           [-0.0310, -0.0027,  0.0195,  0.0477, -0.0690],
#           [ 0.1127, -0.0146,  0.0052, -0.0313,  0.0605]],
#
#          [[-0.1174,  0.0677, -0.0731,  0.1171,  0.0484],
#           [-0.0934,  0.0855, -0.0585,  0.1167,  0.0963],
#           [ 0.0658,  0.0568, -0.0961, -0.0821, -0.0191],
#           [-0.0256, -0.1063,  0.1127, -0.0713, -0.1004]]],
#
#
#         [[[ 0.1112, -0.0004, -0.0344, -0.1121,  0.0834],
#           [ 0.0033, -0.1007, -0.0742, -0.0105, -0.0784],
#           [ 0.1111,  0.0445, -0.0319,  0.0522, -0.1274],
#           [-0.0017, -0.0547,  0.0667,  0.0067, -0.1286]],
#
#          [[-0.1185, -0.0309,  0.0822, -0.1066,  0.0966],
#           [ 0.0578,  0.0212,  0.0918, -0.1280,  0.0866],
#           [-0.0992, -0.0436,  0.0984,  0.0930,  0.1050],
#           [ 0.0062,  0.0374,  0.1247,  0.0672,  0.1166]],
#
#          [[ 0.0810,  0.0583,  0.1138, -0.0746,  0.1220],
#           [-0.1083,  0.0150, -0.0676, -0.0257, -0.0106],
#           [-0.0055,  0.0731,  0.0049, -0.0578, -0.0912],
#           [-0.0204,  0.0641, -0.0875, -0.0381, -0.0377]]]], requires_grad=True)
# param:
# Parameter containing:
# tensor([ 0.0083, -0.0187,  0.0657,  0.0971,  0.0964, -0.0563],
#        requires_grad=True)
# *******************************************************************************
# param name: weight
# param value:
# Parameter containing:
# tensor([[[[ 0.0387,  0.1239,  0.0778, -0.1054, -0.0785],
#           [ 0.0686, -0.0441,  0.1030, -0.1146,  0.0502],
#           [-0.0848, -0.0677,  0.0899, -0.1166,  0.0716],
#           [-0.0855,  0.0031,  0.0800,  0.0978, -0.0279]],
#
#          [[-0.0388,  0.0523,  0.0908,  0.0155, -0.1143],
#           [ 0.0673,  0.1113,  0.1271, -0.0353, -0.0797],
#           [ 0.1083, -0.0738,  0.0285, -0.1175,  0.0549],
#           [ 0.0123, -0.0157, -0.0755,  0.0169, -0.1232]],
#
#          [[ 0.0446,  0.0992,  0.0155,  0.0110, -0.0657],
#           [-0.0301,  0.1129,  0.0429, -0.0961,  0.0464],
#           [-0.0254,  0.0151, -0.1281, -0.1192, -0.0042],
#           [-0.1161, -0.0056, -0.1036, -0.1120, -0.0275]]],
#
#
#         [[[-0.0276, -0.1274,  0.1200,  0.0728, -0.0781],
#           [ 0.0503, -0.0444,  0.0349, -0.0902,  0.1009],
#           [ 0.0773,  0.0991, -0.1223,  0.0405,  0.0545],
#           [-0.0153, -0.0044, -0.0881, -0.1129, -0.0490]],
#
#          [[ 0.1279, -0.1193,  0.0865, -0.0482,  0.0793],
#           [ 0.0264,  0.0647, -0.0968, -0.0486,  0.0585],
#           [-0.1159, -0.1173, -0.0581, -0.0679,  0.0054],
#           [-0.0547, -0.0450, -0.1259,  0.0602,  0.0112]],
#
#          [[-0.0944, -0.0915,  0.0515, -0.0467, -0.1130],
#           [-0.0373,  0.0603, -0.0563,  0.0558,  0.0302],
#           [-0.0864, -0.0941,  0.0515,  0.0399,  0.0824],
#           [-0.0399, -0.1228, -0.0576,  0.1249,  0.0927]]],
#
#
#         [[[-0.0276,  0.0098, -0.0822,  0.0349,  0.1058],
#           [ 0.0155,  0.0837, -0.0519,  0.0067,  0.0126],
#           [ 0.0047, -0.1169, -0.0058, -0.0997, -0.0345],
#           [-0.0011, -0.0903,  0.0015,  0.0901, -0.0271]],
#
#          [[ 0.1232,  0.1289,  0.0742, -0.1032, -0.0938],
#           [ 0.0823,  0.0318,  0.0757,  0.1206,  0.1099],
#           [-0.0212,  0.0300,  0.0009, -0.0828, -0.0986],
#           [-0.1023, -0.0367,  0.0073,  0.0543, -0.0307]],
#
#          [[-0.1175, -0.0579,  0.0780, -0.0340, -0.0523],
#           [-0.1213, -0.0219,  0.0264, -0.1001,  0.0251],
#           [ 0.0511,  0.1114,  0.0038,  0.0315,  0.0388],
#           [-0.0934,  0.1284, -0.0717, -0.1256, -0.0640]]],
#
#
#         [[[ 0.0079, -0.0270,  0.0750, -0.0190,  0.1030],
#           [-0.0092,  0.0427,  0.1155, -0.0557,  0.0477],
#           [-0.0105, -0.0310, -0.0840,  0.0863, -0.1061],
#           [ 0.1015,  0.0300,  0.0154,  0.0978, -0.0532]],
#
#          [[-0.0530, -0.1128,  0.0805, -0.0537,  0.0414],
#           [-0.0250, -0.0571, -0.0684, -0.0764,  0.0482],
#           [-0.0944,  0.0935,  0.0958,  0.1070, -0.0584],
#           [-0.1201,  0.0355,  0.0408, -0.0659, -0.1010]],
#
#          [[ 0.1282, -0.0350, -0.0356,  0.0961, -0.1271],
#           [-0.1143, -0.0286,  0.0900,  0.1208, -0.1123],
#           [ 0.0485,  0.0309, -0.0969,  0.0974,  0.1145],
#           [ 0.0005, -0.0475, -0.0373, -0.0894, -0.1263]]],
#
#
#         [[[-0.0638, -0.1116,  0.0288, -0.0626, -0.0006],
#           [-0.0615, -0.0276, -0.0032,  0.1267, -0.0900],
#           [-0.0194,  0.0377, -0.0743, -0.0167,  0.1040],
#           [-0.1144, -0.0862,  0.0144,  0.0886, -0.0310]],
#
#          [[-0.0251,  0.0983, -0.1110,  0.1187,  0.0602],
#           [ 0.0621, -0.0239,  0.0923, -0.0558, -0.0673],
#           [-0.0310, -0.0027,  0.0195,  0.0477, -0.0690],
#           [ 0.1127, -0.0146,  0.0052, -0.0313,  0.0605]],
#
#          [[-0.1174,  0.0677, -0.0731,  0.1171,  0.0484],
#           [-0.0934,  0.0855, -0.0585,  0.1167,  0.0963],
#           [ 0.0658,  0.0568, -0.0961, -0.0821, -0.0191],
#           [-0.0256, -0.1063,  0.1127, -0.0713, -0.1004]]],
#
#
#         [[[ 0.1112, -0.0004, -0.0344, -0.1121,  0.0834],
#           [ 0.0033, -0.1007, -0.0742, -0.0105, -0.0784],
#           [ 0.1111,  0.0445, -0.0319,  0.0522, -0.1274],
#           [-0.0017, -0.0547,  0.0667,  0.0067, -0.1286]],
#
#          [[-0.1185, -0.0309,  0.0822, -0.1066,  0.0966],
#           [ 0.0578,  0.0212,  0.0918, -0.1280,  0.0866],
#           [-0.0992, -0.0436,  0.0984,  0.0930,  0.1050],
#           [ 0.0062,  0.0374,  0.1247,  0.0672,  0.1166]],
#
#          [[ 0.0810,  0.0583,  0.1138, -0.0746,  0.1220],
#           [-0.1083,  0.0150, -0.0676, -0.0257, -0.0106],
#           [-0.0055,  0.0731,  0.0049, -0.0578, -0.0912],
#           [-0.0204,  0.0641, -0.0875, -0.0381, -0.0377]]]], requires_grad=True)
# param name: bias
# param value:
# Parameter containing:
# tensor([ 0.0083, -0.0187,  0.0657,  0.0971,  0.0964, -0.0563],
#        requires_grad=True)
# *******************************************************************************
# number of parameters: 2 (=2)
# *******************************************************************************
# conv layer weight shape: torch.Size([6, 3, 4, 5])
# conv layer bias shape: torch.Size([6])

# %%
# Vanilla recurrent layer.
print('*'*79)
rnn = nn.RNN(input_size=7, hidden_size=3, num_layers=2, bias=True, bidirectional=True)
print('bidirectional rnn layer:\n{}'.format(rnn))
print('*'*79)
for param in rnn.parameters():
    print('param:\n{}'.format(param))
print('*'*79)
for param in rnn.named_parameters():
    print('param name: {}\nparam value:\n{}'.format(param[0], param[1]))
print('*'*79)
print('number of parameters: {} (={})'.format(
    len([_ for _ in rnn.parameters()]), len([_ for _ in rnn.named_parameters()])
))
print('*'*79)
print('*'*79)
rnn = nn.RNN(input_size=7, hidden_size=3, num_layers=2, bias=True, bidirectional=False)
print('vanilla rnn layer:\n{}'.format(rnn))
print('*'*79)
for param in rnn.parameters():
    print('param:\n{}'.format(param))
print('*'*79)
for param in rnn.named_parameters():
    print('param name: {}\nparam value:\n{}'.format(param[0], param[1]))
print('*'*79)
print('number of parameters: {} (={})'.format(
    len([_ for _ in rnn.parameters()]), len([_ for _ in rnn.named_parameters()])
))
print('*'*79)
# Out:
# *******************************************************************************
# bidirectional rnn layer:
# RNN(7, 3, num_layers=2, bidirectional=True)
# *******************************************************************************
# param:
# Parameter containing:
# tensor([[ 0.1433,  0.0512, -0.1738,  0.2987, -0.0241,  0.0783, -0.3431],
#         [-0.3102, -0.5424,  0.2054,  0.2688,  0.4827, -0.2915, -0.0637],
#         [ 0.0674,  0.3227, -0.1208, -0.0980,  0.0801,  0.5475, -0.0480]],
#        requires_grad=True)
# param:
# Parameter containing:
# tensor([[ 0.1513,  0.3481,  0.4531],
#         [ 0.2473,  0.3999, -0.5677],
#         [ 0.0337, -0.2154,  0.4103]], requires_grad=True)
# param:
# Parameter containing:
# tensor([-0.5614,  0.1699,  0.3528], requires_grad=True)
# param:
# Parameter containing:
# tensor([0.3705, 0.3998, 0.4522], requires_grad=True)
# param:
# Parameter containing:
# tensor([[-0.2418, -0.4999, -0.3313,  0.0535, -0.5116, -0.1570, -0.0919],
#         [ 0.0283, -0.5324,  0.3458, -0.0493,  0.1670,  0.4153,  0.2363],
#         [-0.4071,  0.4279,  0.5384,  0.1935, -0.4769, -0.1461,  0.2759]],
#        requires_grad=True)
# param:
# Parameter containing:
# tensor([[ 4.0081e-01,  3.2306e-04, -1.6942e-01],
#         [-4.4297e-01, -5.5635e-01,  3.5343e-01],
#         [ 1.3593e-01,  2.8281e-01,  1.1658e-01]], requires_grad=True)
# param:
# Parameter containing:
# tensor([0.5492, 0.4420, 0.0442], requires_grad=True)
# param:
# Parameter containing:
# tensor([ 0.4499, -0.4809, -0.3227], requires_grad=True)
# param:
# Parameter containing:
# tensor([[-0.0386,  0.0983,  0.2544, -0.5257, -0.2825, -0.2380],
#         [ 0.3301,  0.3327, -0.2662, -0.2508,  0.2027, -0.0811],
#         [-0.0487, -0.4233,  0.2958, -0.3858,  0.4163, -0.4981]],
#        requires_grad=True)
# param:
# Parameter containing:
# tensor([[ 0.5219, -0.2710,  0.1411],
#         [-0.5604, -0.2644, -0.4412],
#         [ 0.1425, -0.1573,  0.2471]], requires_grad=True)
# param:
# Parameter containing:
# tensor([ 0.4561, -0.1370,  0.2243], requires_grad=True)
# param:
# Parameter containing:
# tensor([-0.3350,  0.4572, -0.0220], requires_grad=True)
# param:
# Parameter containing:
# tensor([[-0.5357, -0.4384,  0.5106,  0.4460,  0.1927, -0.0393],
#         [ 0.3885, -0.0891,  0.1034,  0.0434,  0.1224,  0.0013],
#         [-0.2685,  0.5479, -0.4083,  0.4463, -0.4531,  0.1164]],
#        requires_grad=True)
# param:
# Parameter containing:
# tensor([[ 0.1732, -0.3458, -0.1893],
#         [ 0.0026,  0.1384, -0.5273],
#         [-0.3176, -0.0889,  0.2967]], requires_grad=True)
# param:
# Parameter containing:
# tensor([-0.3308,  0.4410, -0.3397], requires_grad=True)
# param:
# Parameter containing:
# tensor([-0.5210, -0.1363,  0.0756], requires_grad=True)
# *******************************************************************************
# param name: weight_ih_l0
# param value:
# Parameter containing:
# tensor([[ 0.1433,  0.0512, -0.1738,  0.2987, -0.0241,  0.0783, -0.3431],
#         [-0.3102, -0.5424,  0.2054,  0.2688,  0.4827, -0.2915, -0.0637],
#         [ 0.0674,  0.3227, -0.1208, -0.0980,  0.0801,  0.5475, -0.0480]],
#        requires_grad=True)
# param name: weight_hh_l0
# param value:
# Parameter containing:
# tensor([[ 0.1513,  0.3481,  0.4531],
#         [ 0.2473,  0.3999, -0.5677],
#         [ 0.0337, -0.2154,  0.4103]], requires_grad=True)
# param name: bias_ih_l0
# param value:
# Parameter containing:
# tensor([-0.5614,  0.1699,  0.3528], requires_grad=True)
# param name: bias_hh_l0
# param value:
# Parameter containing:
# tensor([0.3705, 0.3998, 0.4522], requires_grad=True)
# param name: weight_ih_l0_reverse
# param value:
# Parameter containing:
# tensor([[-0.2418, -0.4999, -0.3313,  0.0535, -0.5116, -0.1570, -0.0919],
#         [ 0.0283, -0.5324,  0.3458, -0.0493,  0.1670,  0.4153,  0.2363],
#         [-0.4071,  0.4279,  0.5384,  0.1935, -0.4769, -0.1461,  0.2759]],
#        requires_grad=True)
# param name: weight_hh_l0_reverse
# param value:
# Parameter containing:
# tensor([[ 4.0081e-01,  3.2306e-04, -1.6942e-01],
#         [-4.4297e-01, -5.5635e-01,  3.5343e-01],
#         [ 1.3593e-01,  2.8281e-01,  1.1658e-01]], requires_grad=True)
# param name: bias_ih_l0_reverse
# param value:
# Parameter containing:
# tensor([0.5492, 0.4420, 0.0442], requires_grad=True)
# param name: bias_hh_l0_reverse
# param value:
# Parameter containing:
# tensor([ 0.4499, -0.4809, -0.3227], requires_grad=True)
# param name: weight_ih_l1
# param value:
# Parameter containing:
# tensor([[-0.0386,  0.0983,  0.2544, -0.5257, -0.2825, -0.2380],
#         [ 0.3301,  0.3327, -0.2662, -0.2508,  0.2027, -0.0811],
#         [-0.0487, -0.4233,  0.2958, -0.3858,  0.4163, -0.4981]],
#        requires_grad=True)
# param name: weight_hh_l1
# param value:
# Parameter containing:
# tensor([[ 0.5219, -0.2710,  0.1411],
#         [-0.5604, -0.2644, -0.4412],
#         [ 0.1425, -0.1573,  0.2471]], requires_grad=True)
# param name: bias_ih_l1
# param value:
# Parameter containing:
# tensor([ 0.4561, -0.1370,  0.2243], requires_grad=True)
# param name: bias_hh_l1
# param value:
# Parameter containing:
# tensor([-0.3350,  0.4572, -0.0220], requires_grad=True)
# param name: weight_ih_l1_reverse
# param value:
# Parameter containing:
# tensor([[-0.5357, -0.4384,  0.5106,  0.4460,  0.1927, -0.0393],
#         [ 0.3885, -0.0891,  0.1034,  0.0434,  0.1224,  0.0013],
#         [-0.2685,  0.5479, -0.4083,  0.4463, -0.4531,  0.1164]],
#        requires_grad=True)
# param name: weight_hh_l1_reverse
# param value:
# Parameter containing:
# tensor([[ 0.1732, -0.3458, -0.1893],
#         [ 0.0026,  0.1384, -0.5273],
#         [-0.3176, -0.0889,  0.2967]], requires_grad=True)
# param name: bias_ih_l1_reverse
# param value:
# Parameter containing:
# tensor([-0.3308,  0.4410, -0.3397], requires_grad=True)
# param name: bias_hh_l1_reverse
# param value:
# Parameter containing:
# tensor([-0.5210, -0.1363,  0.0756], requires_grad=True)
# *******************************************************************************
# number of parameters: 16 (=16)
# *******************************************************************************
# *******************************************************************************
# vanilla rnn layer:
# RNN(7, 3, num_layers=2)
# *******************************************************************************
# param:
# Parameter containing:
# tensor([[-0.4087, -0.1613,  0.2376,  0.5564, -0.3821,  0.3232, -0.5033],
#         [-0.2720, -0.0958, -0.3385, -0.2847, -0.3930,  0.4908,  0.5347],
#         [ 0.4476,  0.1337, -0.4079, -0.3122, -0.4992,  0.4588,  0.1302]],
#        requires_grad=True)
# param:
# Parameter containing:
# tensor([[-0.0967,  0.2733, -0.1498],
#         [-0.2566,  0.3585,  0.3269],
#         [-0.4085,  0.3158,  0.5691]], requires_grad=True)
# param:
# Parameter containing:
# tensor([-0.3587, -0.0848,  0.2672], requires_grad=True)
# param:
# Parameter containing:
# tensor([-0.2428,  0.3252, -0.4977], requires_grad=True)
# param:
# Parameter containing:
# tensor([[-0.3761,  0.5340, -0.4177],
#         [ 0.1843, -0.5142, -0.2355],
#         [ 0.2573, -0.4152, -0.4493]], requires_grad=True)
# param:
# Parameter containing:
# tensor([[ 0.0011,  0.5058,  0.0408],
#         [-0.4937,  0.5354, -0.1191],
#         [-0.1543,  0.5464, -0.3157]], requires_grad=True)
# param:
# Parameter containing:
# tensor([0.5498, 0.0360, 0.4523], requires_grad=True)
# param:
# Parameter containing:
# tensor([-0.1318,  0.0077,  0.3616], requires_grad=True)
# *******************************************************************************
# param name: weight_ih_l0
# param value:
# Parameter containing:
# tensor([[-0.4087, -0.1613,  0.2376,  0.5564, -0.3821,  0.3232, -0.5033],
#         [-0.2720, -0.0958, -0.3385, -0.2847, -0.3930,  0.4908,  0.5347],
#         [ 0.4476,  0.1337, -0.4079, -0.3122, -0.4992,  0.4588,  0.1302]],
#        requires_grad=True)
# param name: weight_hh_l0
# param value:
# Parameter containing:
# tensor([[-0.0967,  0.2733, -0.1498],
#         [-0.2566,  0.3585,  0.3269],
#         [-0.4085,  0.3158,  0.5691]], requires_grad=True)
# param name: bias_ih_l0
# param value:
# Parameter containing:
# tensor([-0.3587, -0.0848,  0.2672], requires_grad=True)
# param name: bias_hh_l0
# param value:
# Parameter containing:
# tensor([-0.2428,  0.3252, -0.4977], requires_grad=True)
# param name: weight_ih_l1
# param value:
# Parameter containing:
# tensor([[-0.3761,  0.5340, -0.4177],
#         [ 0.1843, -0.5142, -0.2355],
#         [ 0.2573, -0.4152, -0.4493]], requires_grad=True)
# param name: weight_hh_l1
# param value:
# Parameter containing:
# tensor([[ 0.0011,  0.5058,  0.0408],
#         [-0.4937,  0.5354, -0.1191],
#         [-0.1543,  0.5464, -0.3157]], requires_grad=True)
# param name: bias_ih_l1
# param value:
# Parameter containing:
# tensor([0.5498, 0.0360, 0.4523], requires_grad=True)
# param name: bias_hh_l1
# param value:
# Parameter containing:
# tensor([-0.1318,  0.0077,  0.3616], requires_grad=True)
# *******************************************************************************
# number of parameters: 8 (=8)
# *******************************************************************************

# %%
# Long Short Term Memory (LSTM) and variants with `bias=False`, `bidirectional=False`
lstm = nn.LSTM(input_size=7, hidden_size=3, num_layers=2, bias=True, bidirectional=True)
print('bidirectional lstm layer:\n{}'.format(lstm))
print('*'*79)
for param in lstm.named_parameters():
    print('param name: {}\nparam value:\n{}'.format(param[0], param[1]))
print('*'*79)
print('number of parameters: {} (={})'.format(
    len([_ for _ in lstm.parameters()]), len([_ for _ in lstm.named_parameters()])
))
print('*'*79)
# Out:
# bidirectional rnn layer:
# LSTM(7, 3, num_layers=2, bidirectional=True)
# *******************************************************************************
# param name: weight_ih_l0
# param value:
# Parameter containing:
# tensor([[ 0.5433,  0.1038, -0.2110, -0.3104, -0.4350, -0.1444, -0.3498],
#         [-0.4919, -0.3306,  0.2637,  0.0951, -0.3271,  0.5270,  0.2897],
#         [-0.3156,  0.0363, -0.5236,  0.3686, -0.0076,  0.4734,  0.0722],
#         [-0.4724,  0.4088, -0.2999, -0.2423, -0.3757, -0.2682, -0.2645],
#         [ 0.3096,  0.1195, -0.1634,  0.0052, -0.1144, -0.4067, -0.1990],
#         [-0.2592,  0.2956, -0.2253,  0.3354,  0.4368, -0.4077, -0.0589],
#         [-0.5396,  0.2206, -0.1965,  0.0478, -0.1008,  0.4866,  0.4834],
#         [-0.0953, -0.1377,  0.1541, -0.4141, -0.4252, -0.5530,  0.3502],
#         [ 0.2661, -0.3202,  0.3023, -0.0863,  0.0873, -0.3209,  0.5054],
#         [ 0.1389, -0.4313,  0.4500,  0.4513,  0.4787, -0.0702,  0.1273],
#         [-0.5655,  0.3049,  0.1546,  0.3812, -0.2219,  0.0119, -0.3321],
#         [ 0.4869,  0.5244,  0.1661,  0.2102, -0.1225,  0.2711, -0.4052]],
#        requires_grad=True)
# param name: weight_hh_l0
# param value:
# Parameter containing:
# tensor([[-0.5749,  0.5465, -0.1639],
#         [-0.0190,  0.1604, -0.2176],
#         [-0.0844, -0.3023, -0.2192],
#         [ 0.0163, -0.1937, -0.3376],
#         [-0.0838, -0.0467, -0.2735],
#         [-0.5197, -0.0613, -0.5452],
#         [-0.3489, -0.3220, -0.1459],
#         [-0.3485, -0.1071,  0.4977],
#         [ 0.3569, -0.2620,  0.4932],
#         [ 0.2260, -0.4513,  0.5467],
#         [ 0.4154, -0.0572, -0.5568],
#         [ 0.4738,  0.1268,  0.3492]], requires_grad=True)
# param name: bias_ih_l0
# param value:
# Parameter containing:
# tensor([ 0.3735,  0.1126,  0.2839, -0.0592,  0.1075, -0.1130, -0.2521, -0.3679,
#         -0.5144, -0.4933, -0.1247,  0.5078], requires_grad=True)
# param name: bias_hh_l0
# param value:
# Parameter containing:
# tensor([-0.0550, -0.5596,  0.3631, -0.1908,  0.1632,  0.5205, -0.2009, -0.3991,
#         -0.5628,  0.1084, -0.4791,  0.5461], requires_grad=True)
# param name: weight_ih_l0_reverse
# param value:
# Parameter containing:
# tensor([[ 0.2843,  0.3741, -0.3762,  0.1579,  0.3779, -0.2355,  0.3014],
#         [-0.4335,  0.0913, -0.2817,  0.3918,  0.5372, -0.4322, -0.4351],
#         [-0.0184,  0.0479,  0.0043, -0.4185,  0.0463,  0.2648, -0.2766],
#         [-0.0512,  0.4846,  0.3113, -0.3840, -0.3573,  0.5770, -0.5452],
#         [ 0.3205, -0.0423,  0.1604,  0.4414, -0.5491, -0.1460,  0.4448],
#         [ 0.0871, -0.1067,  0.2314,  0.4324,  0.5275, -0.3620,  0.2999],
#         [ 0.1553, -0.0672, -0.4115,  0.0505, -0.4160, -0.4924, -0.3929],
#         [ 0.1563, -0.4024,  0.3433, -0.2223, -0.0625,  0.2777, -0.5411],
#         [ 0.4635,  0.3713, -0.2662, -0.1604, -0.3949,  0.4541,  0.2640],
#         [ 0.2054,  0.3191, -0.4971, -0.4954,  0.4224, -0.5105, -0.5356],
#         [-0.4403,  0.3902,  0.3298, -0.0067, -0.2947,  0.4539,  0.3013],
#         [ 0.2263, -0.0706, -0.2080, -0.3322, -0.0393,  0.4769,  0.1109]],
#        requires_grad=True)
# param name: weight_hh_l0_reverse
# param value:
# Parameter containing:
# tensor([[-0.5090, -0.1885, -0.5600],
#         [-0.1733, -0.4302,  0.5396],
#         [-0.4660,  0.4934, -0.2571],
#         [ 0.3959, -0.1933,  0.3027],
#         [ 0.3474,  0.2631, -0.1722],
#         [ 0.4319, -0.5099, -0.0092],
#         [ 0.0327,  0.2407,  0.5400],
#         [-0.1332,  0.1238,  0.0456],
#         [-0.1700, -0.5553, -0.1010],
#         [-0.4171,  0.0224,  0.1798],
#         [-0.0683,  0.1594, -0.0046],
#         [ 0.5180, -0.1717,  0.1203]], requires_grad=True)
# param name: bias_ih_l0_reverse
# param value:
# Parameter containing:
# tensor([ 0.0454, -0.3070, -0.1332,  0.1576,  0.0907, -0.2648,  0.0014,  0.3060,
#         -0.2459,  0.2997, -0.1236,  0.0770], requires_grad=True)
# param name: bias_hh_l0_reverse
# param value:
# Parameter containing:
# tensor([-0.0204,  0.0202, -0.4706,  0.4109,  0.0111, -0.0741,  0.5705, -0.1179,
#         -0.4725, -0.1104, -0.2812,  0.5106], requires_grad=True)
# param name: weight_ih_l1
# param value:
# Parameter containing:
# tensor([[-0.0256,  0.3869,  0.5516,  0.3272, -0.1883, -0.0185],
#         [ 0.1233, -0.3940, -0.0355, -0.1395,  0.4474, -0.2239],
#         [-0.3518,  0.5712, -0.3710,  0.0785, -0.0741, -0.3150],
#         [ 0.1272, -0.0730,  0.2182,  0.2869,  0.4421,  0.5267],
#         [-0.2366,  0.2016,  0.1500,  0.0419, -0.1651, -0.2910],
#         [-0.2153, -0.3063, -0.5463, -0.5456, -0.4986, -0.1875],
#         [ 0.2688, -0.3203,  0.5563,  0.2475, -0.0301, -0.1320],
#         [-0.0806,  0.5392,  0.3906, -0.1770, -0.2269,  0.1306],
#         [-0.3382, -0.1748,  0.2968, -0.4601, -0.3491,  0.3020],
#         [-0.5196, -0.5651, -0.5386, -0.2300,  0.4246, -0.1103],
#         [ 0.1578,  0.2576, -0.1927, -0.0098,  0.5333,  0.4702],
#         [ 0.3759, -0.2360,  0.1955, -0.2188, -0.3143,  0.2389]],
#        requires_grad=True)
# param name: weight_hh_l1
# param value:
# Parameter containing:
# tensor([[ 0.2666, -0.3068, -0.0371],
#         [ 0.0440,  0.3067, -0.5524],
#         [ 0.1879,  0.1380, -0.5684],
#         [-0.1499, -0.2796,  0.1517],
#         [-0.4377, -0.1656,  0.5178],
#         [-0.5164,  0.0278, -0.4693],
#         [-0.4064, -0.2892,  0.3505],
#         [-0.4778,  0.1864, -0.1208],
#         [-0.3618, -0.0063,  0.0833],
#         [-0.0641, -0.3411, -0.1221],
#         [ 0.3002,  0.4015, -0.4135],
#         [-0.4124, -0.3184, -0.3750]], requires_grad=True)
# param name: bias_ih_l1
# param value:
# Parameter containing:
# tensor([ 0.3162, -0.3360,  0.1156, -0.4463, -0.2989,  0.1773, -0.4819,  0.0173,
#          0.5698,  0.4224, -0.3228, -0.0868], requires_grad=True)
# param name: bias_hh_l1
# param value:
# Parameter containing:
# tensor([ 0.0276, -0.3595,  0.4670,  0.4989,  0.3044,  0.2739, -0.3006, -0.3784,
#         -0.3288,  0.4587,  0.1809,  0.1603], requires_grad=True)
# param name: weight_ih_l1_reverse
# param value:
# Parameter containing:
# tensor([[-0.0014, -0.2023,  0.2344,  0.2296, -0.1362,  0.1085],
#         [ 0.0745, -0.5449,  0.1387, -0.4677, -0.5698,  0.3103],
#         [-0.4631, -0.3412, -0.2966, -0.1145,  0.3176, -0.4614],
#         [ 0.1572, -0.3534,  0.1429,  0.2626, -0.3910,  0.5144],
#         [ 0.3150,  0.3938, -0.4122,  0.4093,  0.3449, -0.5058],
#         [-0.0161,  0.2938, -0.5569, -0.3396, -0.4585, -0.4094],
#         [ 0.2094, -0.2085, -0.2623,  0.4174, -0.5420, -0.2538],
#         [-0.2858,  0.5038, -0.5050, -0.2518,  0.2482, -0.4810],
#         [-0.3174,  0.0168, -0.1756,  0.1191,  0.3741,  0.3356],
#         [ 0.1416,  0.2948, -0.0214,  0.1309, -0.1791, -0.0404],
#         [ 0.4107,  0.1975, -0.3622,  0.0439, -0.3965, -0.4074],
#         [ 0.4241, -0.0155,  0.4262, -0.2021,  0.5477, -0.3002]],
#        requires_grad=True)
# param name: weight_hh_l1_reverse
# param value:
# Parameter containing:
# tensor([[-0.3075, -0.0421, -0.5129],
#         [-0.4801,  0.3636, -0.5550],
#         [-0.4075, -0.3176, -0.1928],
#         [ 0.1418, -0.4009, -0.5601],
#         [-0.4004,  0.2250,  0.1931],
#         [-0.0027,  0.5107,  0.1932],
#         [-0.2826, -0.1886, -0.5581],
#         [ 0.5736,  0.2150, -0.5687],
#         [-0.2893,  0.4583,  0.3770],
#         [ 0.4530, -0.3834, -0.4097],
#         [-0.3657,  0.2269,  0.1623],
#         [-0.4216,  0.3106,  0.5581]], requires_grad=True)
# param name: bias_ih_l1_reverse
# param value:
# Parameter containing:
# tensor([-0.5221,  0.4125, -0.3948,  0.3678, -0.0368,  0.0819, -0.3765, -0.3526,
#         -0.2499,  0.4221, -0.4022, -0.0722], requires_grad=True)
# param name: bias_hh_l1_reverse
# param value:
# Parameter containing:
# tensor([-0.1248,  0.1021,  0.4359,  0.2782,  0.3254, -0.4400,  0.2667,  0.3899,
#          0.2952,  0.3487, -0.4371, -0.1118], requires_grad=True)
# *******************************************************************************
# number of parameters: 16 (=16)
# *******************************************************************************

# %%
# Gated recurrent unit (GRU) and variants with `bias=False`, `bidirectional=False`
gru = nn.GRU(input_size=7, hidden_size=3, num_layers=2, bias=True, bidirectional=True)
print('bidirectional gru layer:\n{}'.format(gru))
print('*'*79)
for param in gru.named_parameters():
    print('param name: {}\nparam value:\n{}'.format(param[0], param[1]))
print('*'*79)
print('number of parameters: {} (={})'.format(
    len([_ for _ in gru.parameters()]), len([_ for _ in gru.named_parameters()])
))
print('*'*79)
# Out:
# bidirectional gru layer:
# GRU(7, 3, num_layers=2, bidirectional=True)
# *******************************************************************************
# param name: weight_ih_l0
# param value:
# Parameter containing:
# tensor([[-0.3999, -0.5689,  0.2804,  0.2479, -0.3600, -0.0287, -0.2918],
#         [ 0.4265,  0.3369,  0.5603, -0.5080,  0.3118,  0.5395, -0.0970],
#         [ 0.5601, -0.2796,  0.5429,  0.5337, -0.3717,  0.2954, -0.3988],
#         [-0.2428, -0.2172,  0.1587,  0.3153, -0.0432, -0.5757, -0.1799],
#         [ 0.2090,  0.4545, -0.5349,  0.2925,  0.5290, -0.5542, -0.1370],
#         [-0.1399, -0.2855, -0.0012, -0.1134, -0.5016, -0.3951,  0.5477],
#         [ 0.1161, -0.0954, -0.0290, -0.5393, -0.0318, -0.2148, -0.5338],
#         [ 0.3792,  0.2699, -0.1008, -0.1262, -0.3191,  0.5485,  0.1139],
#         [ 0.4190, -0.4209,  0.3007,  0.0476, -0.0526, -0.5619,  0.0685]],
#        requires_grad=True)
# param name: weight_hh_l0
# param value:
# Parameter containing:
# tensor([[-0.3839,  0.5737,  0.2372],
#         [-0.5593,  0.5245,  0.4680],
#         [-0.3700,  0.5048,  0.2440],
#         [-0.4768, -0.2012,  0.4188],
#         [ 0.1877, -0.4817, -0.5543],
#         [-0.1140,  0.4661,  0.5193],
#         [-0.3238, -0.1393, -0.0760],
#         [ 0.5272, -0.5227,  0.2612],
#         [-0.1604,  0.3101,  0.5578]], requires_grad=True)
# param name: bias_ih_l0
# param value:
# Parameter containing:
# tensor([ 0.5428,  0.4913, -0.4252, -0.1888, -0.5493, -0.0922,  0.0764, -0.3348,
#          0.2501], requires_grad=True)
# param name: bias_hh_l0
# param value:
# Parameter containing:
# tensor([ 0.0653, -0.1245,  0.2751,  0.3543,  0.2017,  0.5540,  0.3944, -0.0906,
#          0.2529], requires_grad=True)
# param name: weight_ih_l0_reverse
# param value:
# Parameter containing:
# tensor([[-0.0978,  0.4124, -0.4512,  0.4319, -0.3309, -0.0342, -0.3569],
#         [ 0.4065, -0.3146, -0.1206, -0.0100, -0.2174, -0.5377, -0.0478],
#         [-0.0558,  0.4260,  0.5085, -0.0756,  0.3249, -0.3021,  0.3352],
#         [-0.3102,  0.5101,  0.1027, -0.5319, -0.0824,  0.3032,  0.4951],
#         [-0.1890, -0.3057,  0.0677, -0.1899, -0.3653,  0.5031,  0.1603],
#         [-0.3240,  0.0519, -0.5361, -0.1256,  0.0322, -0.1612,  0.2936],
#         [ 0.2096, -0.4032, -0.5751, -0.2066,  0.0629, -0.1393, -0.0409],
#         [ 0.0549, -0.5185,  0.1678,  0.2718,  0.3421,  0.0249, -0.4900],
#         [-0.5759, -0.1859, -0.1156, -0.4562, -0.4955,  0.3631,  0.2806]],
#        requires_grad=True)
# param name: weight_hh_l0_reverse
# param value:
# Parameter containing:
# tensor([[-0.0563,  0.3619, -0.3232],
#         [ 0.5764,  0.4473,  0.5066],
#         [-0.5461,  0.3791,  0.1976],
#         [ 0.4764, -0.4972,  0.3507],
#         [-0.2347, -0.3533,  0.3382],
#         [ 0.5722,  0.1931,  0.0392],
#         [ 0.3994,  0.3554,  0.4143],
#         [-0.2366,  0.0108, -0.4855],
#         [-0.5316,  0.5181,  0.4294]], requires_grad=True)
# param name: bias_ih_l0_reverse
# param value:
# Parameter containing:
# tensor([-0.5151,  0.3831, -0.4865, -0.3139,  0.0100,  0.3254, -0.4958, -0.4877,
#          0.3814], requires_grad=True)
# param name: bias_hh_l0_reverse
# param value:
# Parameter containing:
# tensor([ 0.4596, -0.4987, -0.4541,  0.0416,  0.1504, -0.1903,  0.2704,  0.1171,
#          0.3161], requires_grad=True)
# param name: weight_ih_l1
# param value:
# Parameter containing:
# tensor([[ 0.1052, -0.1842, -0.3213,  0.0662,  0.5519,  0.5593],
#         [-0.2838,  0.1387,  0.3814,  0.3874,  0.0784,  0.2776],
#         [ 0.5738, -0.0064,  0.5299, -0.0217, -0.0798, -0.3283],
#         [-0.3065,  0.0752,  0.4871, -0.4185, -0.0601, -0.3764],
#         [ 0.4321,  0.2536, -0.0168,  0.2815,  0.2432,  0.3549],
#         [ 0.1903, -0.4998,  0.1181,  0.1552,  0.1236, -0.1136],
#         [ 0.1960, -0.1284, -0.3691, -0.2937,  0.0139, -0.4495],
#         [ 0.1517, -0.2146,  0.1145, -0.5376, -0.2943,  0.1180],
#         [ 0.1791, -0.0857,  0.3570, -0.1035, -0.3338, -0.5754]],
#        requires_grad=True)
# param name: weight_hh_l1
# param value:
# Parameter containing:
# tensor([[-0.3023,  0.2127, -0.3191],
#         [-0.5140, -0.4989, -0.1963],
#         [ 0.4001, -0.3334, -0.0558],
#         [-0.2246, -0.3134, -0.0152],
#         [ 0.3800,  0.2908,  0.3399],
#         [ 0.3147,  0.2603,  0.1192],
#         [ 0.2256,  0.2919, -0.3404],
#         [-0.2513,  0.0733, -0.3032],
#         [-0.1111, -0.1115,  0.2047]], requires_grad=True)
# param name: bias_ih_l1
# param value:
# Parameter containing:
# tensor([ 0.1456,  0.0890, -0.4649,  0.3141,  0.0449, -0.2646,  0.1434,  0.0168,
#         -0.2698], requires_grad=True)
# param name: bias_hh_l1
# param value:
# Parameter containing:
# tensor([-0.3864, -0.3440,  0.5120, -0.3243, -0.1547,  0.4420,  0.3005, -0.4008,
#         -0.2988], requires_grad=True)
# param name: weight_ih_l1_reverse
# param value:
# Parameter containing:
# tensor([[ 0.2255, -0.0842,  0.1330, -0.1609,  0.5766, -0.1008],
#         [-0.5378,  0.3103,  0.3599,  0.2149, -0.4525,  0.0547],
#         [-0.1634, -0.0725, -0.4281, -0.0271, -0.4488, -0.4182],
#         [ 0.4089,  0.4140, -0.2964, -0.4346, -0.0010,  0.2949],
#         [ 0.1987,  0.1262, -0.1895, -0.1319,  0.3628, -0.2905],
#         [ 0.0138,  0.1302,  0.0126,  0.2246, -0.5395,  0.1042],
#         [ 0.2435, -0.2286, -0.1786, -0.2183,  0.1327,  0.3491],
#         [-0.1479,  0.2608,  0.5351, -0.0770, -0.5216,  0.5636],
#         [ 0.3451,  0.1092, -0.0278,  0.4968,  0.4534, -0.5222]],
#        requires_grad=True)
# param name: weight_hh_l1_reverse
# param value:
# Parameter containing:
# tensor([[ 0.1503,  0.4140, -0.0390],
#         [-0.0554,  0.3805, -0.3121],
#         [-0.1427, -0.2256, -0.5177],
#         [-0.4549, -0.0845,  0.1665],
#         [ 0.0085,  0.1672,  0.1928],
#         [-0.4362, -0.2480, -0.0810],
#         [ 0.5448, -0.4853, -0.4895],
#         [-0.2556, -0.2751,  0.2980],
#         [-0.0788,  0.5309,  0.4313]], requires_grad=True)
# param name: bias_ih_l1_reverse
# param value:
# Parameter containing:
# tensor([ 0.5074, -0.2229,  0.4301, -0.3625, -0.3520,  0.1828,  0.2944, -0.4347,
#          0.2953], requires_grad=True)
# param name: bias_hh_l1_reverse
# param value:
# Parameter containing:
# tensor([-0.3572, -0.4905, -0.2167,  0.0563,  0.2445, -0.1926, -0.5427, -0.2079,
#          0.4540], requires_grad=True)
# *******************************************************************************
# number of parameters: 16 (=16)
# *******************************************************************************
